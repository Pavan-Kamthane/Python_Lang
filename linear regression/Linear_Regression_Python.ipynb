# %% [markdown]
# # Linear Regression
# ## Predicting Student's marks from Study Hours

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Data

# %%
data = np.genfromtxt('https://raw.githubusercontent.com/kaustubholpadkar/Linear_Regression-Gradient_Descent-Octave/master/data.csv', delimiter=',')

# %%
data.shape
# Out:
# (100, 2)

# %%
print(data)
# Out:
# [[ 32.50234527  31.70700585]
#  [ 53.42680403  68.77759598]
#  [ 61.53035803  62.5623823 ]
#  [ 47.47563963  71.54663223]
#  [ 59.81320787  87.23092513]
#  [ 55.14218841  78.21151827]
#  [ 52.21179669  79.64197305]
#  [ 39.29956669  59.17148932]
#  [ 48.10504169  75.3312423 ]
#  [ 52.55001444  71.30087989]
#  [ 45.41973014  55.16567715]
#  [ 54.35163488  82.47884676]
#  [ 44.1640495   62.00892325]
#  [ 58.16847072  75.39287043]
#  [ 56.72720806  81.43619216]
#  [ 48.95588857  60.72360244]
#  [ 44.68719623  82.89250373]
#  [ 60.29732685  97.37989686]
#  [ 45.61864377  48.84715332]
#  [ 38.81681754  56.87721319]
#  [ 66.18981661  83.87856466]
#  [ 65.41605175 118.5912173 ]
#  [ 47.48120861  57.25181946]
#  [ 41.57564262  51.39174408]
#  [ 51.84518691  75.38065167]
#  [ 59.37082201  74.76556403]
#  [ 57.31000344  95.45505292]
#  [ 63.61556125  95.22936602]
#  [ 46.73761941  79.05240617]
#  [ 50.55676015  83.43207142]
#  [ 52.22399609  63.35879032]
#  [ 35.56783005  41.4128853 ]
#  [ 42.43647694  76.61734128]
#  [ 58.16454011  96.76956643]
#  [ 57.50444762  74.08413012]
#  [ 45.44053073  66.58814441]
#  [ 61.89622268  77.76848242]
#  [ 33.09383174  50.71958891]
#  [ 36.43600951  62.12457082]
#  [ 37.67565486  60.81024665]
#  [ 44.55560838  52.68298337]
#  [ 43.31828263  58.56982472]
#  [ 50.07314563  82.90598149]
#  [ 43.87061265  61.4247098 ]
#  [ 62.99748075 115.2441528 ]
#  [ 32.66904376  45.57058882]
#  [ 40.16689901  54.0840548 ]
#  [ 53.57507753  87.99445276]
#  [ 33.86421497  52.72549438]
#  [ 64.70713867  93.57611869]
#  [ 38.11982403  80.16627545]
#  [ 44.50253806  65.10171157]
#  [ 40.59953838  65.56230126]
#  [ 41.72067636  65.28088692]
#  [ 51.08863468  73.43464155]
#  [ 55.0780959   71.13972786]
#  [ 41.37772653  79.10282968]
#  [ 62.49469743  86.52053844]
#  [ 49.20388754  84.74269781]
#  [ 41.10268519  59.35885025]
#  [ 41.18201611  61.68403752]
#  [ 50.18638949  69.84760416]
#  [ 52.37844622  86.09829121]
#  [ 50.13548549  59.10883927]
#  [ 33.64470601  69.89968164]
#  [ 39.55790122  44.86249071]
#  [ 56.13038882  85.49806778]
#  [ 57.36205213  95.53668685]
#  [ 60.26921439  70.25193442]
#  [ 35.67809389  52.72173496]
#  [ 31.588117    50.39267014]
#  [ 53.66093226  63.64239878]
#  [ 46.68222865  72.24725107]
#  [ 43.10782022  57.81251298]
#  [ 70.34607562 104.25710159]
#  [ 44.49285588  86.64202032]
#  [ 57.5045333   91.486778  ]
#  [ 36.93007661  55.23166089]
#  [ 55.80573336  79.55043668]
#  [ 38.95476907  44.84712424]
#  [ 56.9012147   80.20752314]
#  [ 56.86890066  83.14274979]
#  [ 34.3331247   55.72348926]
#  [ 59.04974121  77.63418251]
#  [ 57.78822399  99.05141484]
#  [ 54.28232871  79.12064627]
#  [ 51.0887199   69.58889785]
#  [ 50.28283635  69.51050331]
#  [ 44.21174175  73.68756432]
#  [ 38.00548801  61.36690454]
#  [ 32.94047994  67.17065577]
#  [ 53.69163957  85.66820315]
#  [ 68.76573427 114.85387123]
#  [ 46.2309665   90.12357207]
#  [ 68.31936082  97.91982104]
#  [ 50.03017434  81.53699078]
#  [ 49.23976534  72.11183247]
#  [ 50.03957594  85.23200734]
#  [ 48.14985889  66.22495789]
#  [ 25.12848465  53.45439421]]

# %% [markdown]
# ### Seperate Data into X and Y

# %%
X = data[:, 0]
Y = data[:, 1]

# %% [markdown]
# ### Visualize the Data

# %%
fig = plt.figure()
plt.scatter(X, Y)
fig.suptitle('Student Data : Expected Marks vs Hours of Study', fontsize=18)
plt.xlabel('Hours of Study', fontsize=14)
plt.ylabel('Expected Marks', fontsize=14)
plt.show()

# %% [markdown]
# ### Hyperparameters

# %%
learning_rate = 0.0001
max_iteration = 50
m=0
b=0

# %% [markdown]
# ### Parameters

# %% [markdown]
# ### Hypothesis

# %%
for m in range(-4,5):
    for b in range (3,10):
        def h (m, b, X) :
          return m * X + b
        def loss (m, b, X, Y) :
           return np.average(np.square(Y - h(m, b, X))) / 2
        def gradient (m, b, X, Y) :
          dm = - np.average((Y - h(m, b, X)) * X)
          db = - np.average(Y - h(m, b, X))
          return (dm, db)
        Loss_list=[]
        m_list=[]
        b_list=[]
        def gradient_descent (m, b, X, Y, learning_rate, max_iteration) :
          for i in range(max_iteration) :
            dm, db = gradient (m, b, X, Y)
            m -= learning_rate * dm
            b -= learning_rate * db
            m_list.append(m)
            b_list.append(b)
            Loss_list.append(loss(m, b, X, Y))
            if i % 10 == 0 :
                 print ('iteration : ', i, ' loss : ', loss(m, b, X, Y)) 
          return (m, b)
          
        m, b = gradient_descent (m, b, X, Y, learning_rate, max_iteration)
        
        
        f = plt.figure()
        plt.plot(Loss_list)
        plt.show()
# Out:
# iteration :  0  loss :  20684.548565617788
# iteration :  10  loss :  122.42132199762759
# iteration :  20  loss :  55.79557354179874
# iteration :  30  loss :  55.579657911549404
# iteration :  40  loss :  55.57892442501071
# iteration :  0  loss :  55.645417240154735
# iteration :  10  loss :  55.43009051882758
# iteration :  20  loss :  55.42937019231697
# iteration :  30  loss :  55.42934523838842
# iteration :  40  loss :  55.42932253932384
# iteration :  0  loss :  55.568610486853814
# iteration :  10  loss :  55.29847378840109
# iteration :  20  loss :  55.297585780729705
# iteration :  30  loss :  55.29757019768297
# iteration :  40  loss :  55.2975574424386
# iteration :  0  loss :  55.47467717316745
# iteration :  10  loss :  55.20442318723289
# iteration :  20  loss :  55.20354187499635
# iteration :  30  loss :  55.20353338858171
# iteration :  40  loss :  55.20352773073542
# iteration :  0  loss :  55.418474457171094
# iteration :  10  loss :  55.14812266615433
# iteration :  20  loss :  55.147245272530014
# iteration :  30  loss :  55.1472410340146
# iteration :  40  loss :  55.14723962481486
# iteration :  0  loss :  55.40002475571298
# iteration :  10  loss :  55.12957229959827
# iteration :  20  loss :  55.128695975369254
# iteration :  30  loss :  55.128693135785454
# iteration :  40  loss :  55.12869312647976
# iteration :  0  loss :  55.41932807746289
# iteration :  10  loss :  55.14877208759329
# iteration :  20  loss :  55.147893983514656
# iteration :  30  loss :  55.14788969389474
# iteration :  40  loss :  55.14788823573063
# iteration :  0  loss :  13775.22035589065
# iteration :  10  loss :  100.03723088801124
# iteration :  20  loss :  55.726662282243716
# iteration :  30  loss :  55.58305236097821
# iteration :  40  loss :  55.58255288743976
# iteration :  0  loss :  55.65504721117873
# iteration :  10  loss :  55.43012286300082
# iteration :  20  loss :  55.42937143802893
# iteration :  30  loss :  55.42934638324858
# iteration :  40  loss :  55.42932368377109
# iteration :  0  loss :  55.56861461218565
# iteration :  10  loss :  55.298473802098705
# iteration :  20  loss :  55.29758578110473
# iteration :  30  loss :  55.29757019801479
# iteration :  40  loss :  55.297557442770255
# iteration :  0  loss :  55.47467717476297
# iteration :  10  loss :  55.20442318723817
# iteration :  20  loss :  55.203541874996446
# iteration :  30  loss :  55.20353338858179
# iteration :  40  loss :  55.20352773073552
# iteration :  0  loss :  55.41847445717171
# iteration :  10  loss :  55.14812266615434
# iteration :  20  loss :  55.14724527253001
# iteration :  30  loss :  55.1472410340146
# iteration :  40  loss :  55.147239624814844
# iteration :  0  loss :  55.40002475571298
# iteration :  10  loss :  55.12957229959827
# iteration :  20  loss :  55.128695975369254
# iteration :  30  loss :  55.128693135785454
# iteration :  40  loss :  55.12869312647976
# iteration :  0  loss :  55.41932807746289
# iteration :  10  loss :  55.14877208759329
# iteration :  20  loss :  55.147893983514656
# iteration :  30  loss :  55.14788969389474
# iteration :  40  loss :  55.14788823573063
# iteration :  0  loss :  8270.077202001847
# iteration :  10  loss :  82.20301588282979
# iteration :  20  loss :  55.672508123387786
# iteration :  30  loss :  55.5865091490673
# iteration :  40  loss :  55.58619607324362
# iteration :  0  loss :  55.66488714057302
# iteration :  10  loss :  55.430155887486514
# iteration :  20  loss :  55.42937268594742
# iteration :  30  loss :  55.42934752811804
# iteration :  40  loss :  55.42932482822056
# iteration :  0  loss :  55.56861873754886
# iteration :  10  loss :  55.29847381579644
# iteration :  20  loss :  55.297585781479775
# iteration :  30  loss :  55.29757019834661
# iteration :  40  loss :  55.29755744310193
# iteration :  0  loss :  55.474677176358476
# iteration :  10  loss :  55.20442318724341
# iteration :  20  loss :  55.203541874996546
# iteration :  30  loss :  55.20353338858189
# iteration :  40  loss :  55.203527730735615
# iteration :  0  loss :  55.41847445717231
# iteration :  10  loss :  55.14812266615432
# iteration :  20  loss :  55.147245272530014
# iteration :  30  loss :  55.1472410340146
# iteration :  40  loss :  55.147239624814844
# iteration :  0  loss :  55.40002475571298
# iteration :  10  loss :  55.12957229959827
# iteration :  20  loss :  55.128695975369254
# iteration :  30  loss :  55.128693135785454
# iteration :  40  loss :  55.12869312647976
# iteration :  0  loss :  55.41932807746289
# iteration :  10  loss :  55.14877208759329
# iteration :  20  loss :  55.147893983514656
# iteration :  30  loss :  55.14788969389474
# iteration :  40  loss :  55.14788823573063
# iteration :  0  loss :  4169.119103951385
# iteration :  10  loss :  68.91867698208344
# iteration :  20  loss :  55.63311106523091
# iteration :  30  loss :  55.59002827581668
# iteration :  40  loss :  55.589853982422255
# iteration :  0  loss :  55.674937028337496
# iteration :  10  loss :  55.43018959228465
# iteration :  20  loss :  55.42937393607242
# iteration :  30  loss :  55.42934867299683
# iteration :  40  loss :  55.42932597267223
# iteration :  0  loss :  55.568622862943485
# iteration :  10  loss :  55.29847382949428
# iteration :  20  loss :  55.297585781854785
# iteration :  30  loss :  55.29757019867846
# iteration :  40  loss :  55.29755744343362
# iteration :  0  loss :  55.47467717795399
# iteration :  10  loss :  55.204423187248665
# iteration :  20  loss :  55.203541874996645
# iteration :  30  loss :  55.20353338858197
# iteration :  40  loss :  55.20352773073569
# iteration :  0  loss :  55.41847445717293
# iteration :  10  loss :  55.14812266615432
# iteration :  20  loss :  55.147245272530014
# iteration :  30  loss :  55.1472410340146
# iteration :  40  loss :  55.147239624814844
# iteration :  0  loss :  55.40002475571298
# iteration :  10  loss :  55.12957229959827
# iteration :  20  loss :  55.128695975369254
# iteration :  30  loss :  55.128693135785454
# iteration :  40  loss :  55.12869312647976
# iteration :  0  loss :  55.41932807746289
# iteration :  10  loss :  55.14877208759329
# iteration :  20  loss :  55.147893983514656
# iteration :  30  loss :  55.14788969389474
# iteration :  40  loss :  55.14788823573063
# iteration :  0  loss :  1472.3460617392664
# iteration :  10  loss :  60.18421418577201
# iteration :  20  loss :  55.60847110777311
# iteration :  30  loss :  55.59360974122632
# iteration :  40  loss :  55.593526614975666
# iteration :  0  loss :  55.68519687447226
# iteration :  10  loss :  55.43022397739524
# iteration :  20  loss :  55.42937518840398
# iteration :  30  loss :  55.42934981788495
# iteration :  40  loss :  55.42932711712609
# iteration :  0  loss :  55.568626988369495
# iteration :  10  loss :  55.29847384319223
# iteration :  20  loss :  55.29758578222981
# iteration :  30  loss :  55.29757019901031
# iteration :  40  loss :  55.29755744376527
# iteration :  0  loss :  55.4746771795495
# iteration :  10  loss :  55.204423187253916
# iteration :  20  loss :  55.20354187499675
# iteration :  30  loss :  55.203533388582066
# iteration :  40  loss :  55.20352773073579
# iteration :  0  loss :  55.41847445717356
# iteration :  10  loss :  55.14812266615435
# iteration :  20  loss :  55.147245272530014
# iteration :  30  loss :  55.1472410340146
# iteration :  40  loss :  55.147239624814844
# iteration :  0  loss :  55.40002475571298
# iteration :  10  loss :  55.12957229959827
# iteration :  20  loss :  55.128695975369254
# iteration :  30  loss :  55.128693135785454
# iteration :  40  loss :  55.12869312647976
# iteration :  0  loss :  55.41932807746289
# iteration :  10  loss :  55.14877208759329
# iteration :  20  loss :  55.147893983514656
# iteration :  30  loss :  55.14788969389474
# iteration :  40  loss :  55.14788823573063
# iteration :  0  loss :  179.7580753654878
# iteration :  10  loss :  55.999627493895595
# iteration :  20  loss :  55.59858825101438
# iteration :  30  loss :  55.597253545296255
# iteration :  40  loss :  55.59721397090385
# iteration :  0  loss :  55.69566667897724
# iteration :  10  loss :  55.43025904281825
# iteration :  20  loss :  55.42937644294207
# iteration :  30  loss :  55.42935096278237
# iteration :  40  loss :  55.42932826158216
# iteration :  0  loss :  55.568631113826896
# iteration :  10  loss :  55.29847385689026
# iteration :  20  loss :  55.297585782604855
# iteration :  30  loss :  55.297570199342125
# iteration :  40  loss :  55.29755744409694
# iteration :  0  loss :  55.47467718114502
# iteration :  10  loss :  55.20442318725918
# iteration :  20  loss :  55.20354187499685
# iteration :  30  loss :  55.20353338858215
# iteration :  40  loss :  55.20352773073587
# iteration :  0  loss :  55.41847445717419
# iteration :  10  loss :  55.14812266615432
# iteration :  20  loss :  55.147245272530014
# iteration :  30  loss :  55.1472410340146
# iteration :  40  loss :  55.147239624814844
# iteration :  0  loss :  55.40002475571298
# iteration :  10  loss :  55.12957229959827
# iteration :  20  loss :  55.128695975369254
# iteration :  30  loss :  55.128693135785454
# iteration :  40  loss :  55.12869312647976
# iteration :  0  loss :  55.41932807746289
# iteration :  10  loss :  55.14877208759329
# iteration :  20  loss :  55.147893983514656
# iteration :  30  loss :  55.14788969389474
# iteration :  40  loss :  55.14788823573063
# iteration :  0  loss :  291.3551448300498
# iteration :  10  loss :  56.36491690645419
# iteration :  20  loss :  55.60346249495471
# iteration :  30  loss :  55.60095968802646
# iteration :  40  loss :  55.600916050206834
# iteration :  0  loss :  55.706346441852496
# iteration :  10  loss :  55.43029478855372
# iteration :  20  loss :  55.42937769968667
# iteration :  30  loss :  55.42935210768914
# iteration :  40  loss :  55.42932940604043
# iteration :  0  loss :  55.56863523931571
# iteration :  10  loss :  55.298473870588374
# iteration :  20  loss :  55.297585782979866
# iteration :  30  loss :  55.29757019967397
# iteration :  40  loss :  55.297557444428605
# iteration :  0  loss :  55.47467718274052
# iteration :  10  loss :  55.20442318726443
# iteration :  20  loss :  55.203541874996944
# iteration :  30  loss :  55.20353338858223
# iteration :  40  loss :  55.20352773073595
# iteration :  0  loss :  55.41847445717479
# iteration :  10  loss :  55.14812266615434
# iteration :  20  loss :  55.147245272530014
# iteration :  30  loss :  55.1472410340146
# iteration :  40  loss :  55.147239624814844
# iteration :  0  loss :  55.40002475571298
# iteration :  10  loss :  55.12957229959827
# iteration :  20  loss :  55.128695975369254
# iteration :  30  loss :  55.128693135785454
# iteration :  40  loss :  55.12869312647976
# iteration :  0  loss :  55.41932807746289
# iteration :  10  loss :  55.14877208759329
# iteration :  20  loss :  55.147893983514656
# iteration :  30  loss :  55.14788969389474
# iteration :  40  loss :  55.14788823573063
# iteration :  0  loss :  1807.1372701329528
# iteration :  10  loss :  61.28008242344777
# iteration :  20  loss :  55.62309383959415
# iteration :  30  loss :  55.60472816941696
# iteration :  40  loss :  55.604632852884606
# iteration :  0  loss :  55.717236163097965
# iteration :  10  loss :  55.43033121460166
# iteration :  20  loss :  55.42937895863782
# iteration :  30  loss :  55.429353252605196
# iteration :  40  loss :  55.42933055050089
# iteration :  0  loss :  55.56863936483591
# iteration :  10  loss :  55.29847388428662
# iteration :  20  loss :  55.2975857833549
# iteration :  30  loss :  55.29757020000577
# iteration :  40  loss :  55.297557444760265
# iteration :  0  loss :  55.474677184336024
# iteration :  10  loss :  55.204423187269676
# iteration :  20  loss :  55.203541874997065
# iteration :  30  loss :  55.20353338858231
# iteration :  40  loss :  55.20352773073604
# iteration :  0  loss :  55.418474457175414
# iteration :  10  loss :  55.14812266615433
# iteration :  20  loss :  55.147245272530014
# iteration :  30  loss :  55.1472410340146
# iteration :  40  loss :  55.147239624814844
# iteration :  0  loss :  55.40002475571298
# iteration :  10  loss :  55.12957229959827
# iteration :  20  loss :  55.128695975369254
# iteration :  30  loss :  55.128693135785454
# iteration :  40  loss :  55.12869312647976
# iteration :  0  loss :  55.41932807746289
# iteration :  10  loss :  55.14877208759329
# iteration :  20  loss :  55.147893983514656
# iteration :  30  loss :  55.14788969389474
# iteration :  40  loss :  55.14788823573063
# iteration :  0  loss :  4727.104451274195
# iteration :  10  loss :  70.74512404487635
# iteration :  20  loss :  55.657482284932605
# iteration :  30  loss :  55.60855898946774
# iteration :  40  loss :  55.60836437893715
# iteration :  0  loss :  55.728335842713705
# iteration :  10  loss :  55.43036832096202
# iteration :  20  loss :  55.42938021979548
# iteration :  30  loss :  55.42935439753059
# iteration :  40  loss :  55.429331694963565
# iteration :  0  loss :  55.56864349038747
# iteration :  10  loss :  55.29847389798497
# iteration :  20  loss :  55.297585783729936
# iteration :  30  loss :  55.29757020033763
# iteration :  40  loss :  55.29755744509193
# iteration :  0  loss :  55.47467718593156
# iteration :  10  loss :  55.204423187274934
# iteration :  20  loss :  55.203541874997164
# iteration :  30  loss :  55.20353338858242
# iteration :  40  loss :  55.203527730736134
# iteration :  0  loss :  55.41847445717603
# iteration :  10  loss :  55.14812266615434
# iteration :  20  loss :  55.147245272530014
# iteration :  30  loss :  55.1472410340146
# iteration :  40  loss :  55.147239624814844
# iteration :  0  loss :  55.40002475571298
# iteration :  10  loss :  55.12957229959827
# iteration :  20  loss :  55.128695975369254
# iteration :  30  loss :  55.128693135785454
# iteration :  40  loss :  55.12869312647976
# iteration :  0  loss :  55.41932807746289
# iteration :  10  loss :  55.14877208759329
# iteration :  20  loss :  55.147893983514656
# iteration :  30  loss :  55.14788969389474
# iteration :  40  loss :  55.14788823573063

# %% [markdown]
# ### Loss Function

# %% [markdown]
# Gradient

# %% [markdown]
# ### Gradient Descent

# %%
print(b_list)
# Out:
# [8.999899928734939, 8.999823845976794, 8.999765773976852, 8.999721224595621, 8.999686828103613, 8.999660054482131, 8.999639004173774, 8.999622250976302, 8.999608724086155, 8.999597619535825, 8.999588333700352, 8.999580413373495, 8.99957351828454, 8.999567392955628, 8.999561845572028, 8.999556732117773, 8.99955194446457, 8.999547401428872, 8.999543042057446, 8.999538820586142, 8.999534702654884, 8.999530662465865, 8.999526680649893, 8.99952274266443, 8.999518837590829, 8.999514957231284, 8.999511095430822, 8.99950724756824, 8.999503410173903, 8.999499580642786, 8.99949575701901, 8.999491937834094, 8.999488121985484, 8.99948430864538, 8.999480497192259, 8.99947668715948, 8.99947287819668, 8.99946907004081, 8.999465262494368, 8.999461455409069, 8.999457648673577, 8.999453842204302, 8.999450035938484, 8.999446229829001, 8.999442423840476, 8.999438617946344, 8.999434812126665, 8.999431006366462, 8.999427200654495, 8.99942339498232]

# %% [markdown]
# ### Train Model

# %% [markdown]
# ### Optimal values of Parameters using Trained Model

# %%
m, b
# Out:
# (1.3026111923328312, 8.99942339498232)

# %% [markdown]
# ### Linear Regression using *polyfit*  function of **numpy**

# %%
np_m, np_b = np.polyfit(X, Y, 1)

# %% [markdown]
# ### Optimal values of Parameters using Numpy Linear Regression

# %%
np_m, np_b
# Out:
# (1.3224310227553593, 7.99102098227039)

# %% [markdown]
# ### Visualize the Data

# %%
fig = plt.figure()

# Generate data for plotting Line
x = np.arange(25, 75)
y = [m * x_i + b for x_i in x]

# Generate data for plotting Line Numpy Linear Regression
np_x = np.arange(25, 75)
np_y = [np_m * x_i + np_b for x_i in np_x]

# plot data and best-fit lines
plt.plot(X, Y, 'o', x, y, '-', np_x, np_y, '--')
plt.legend(loc='upper left', labels=['data points', 'best-fit line', 'numpy line'])

fig.suptitle('Linear Regression : Expected Marks vs Hours of Study', fontsize=18)
plt.xlabel('Hours of Study', fontsize=14)
plt.ylabel('Expected Marks', fontsize=14)
plt.show()
